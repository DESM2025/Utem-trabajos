# %% [markdown]
# ## Trabajo unidad 4
#
# Diego Silva
#
# Pablo ibañez

# %% [markdown]
# primero clono el repositorio elegido (https://github.com/health-data-science-OR/simpy-streamlit-tutorial) ; lo clono abriendo la consola de visual studio y ejecuto el siguiente
# comando git clone https://github.com/health-data-science-OR/simpy-streamlit-tutorial.git

# %% [markdown]
# Luego hay que crear el entorno conda tal como lo dice en el README.md del repositorio clonado, para ellos en la consola del visual studio ejecuto
# cd "D:\U\visualizacion\trabajo unidad 4\simpy-streamlit-tutorial" para moverme a la carpeta del repositorio
#
#
# conda env create -f binder/environment.yml para crear el entorno conda desde el archivo environment.yml ubicado dentro de la carpeta blinder del repositorio (conda init powershell)
#
#
# una vez creado el nuevo entorno conda estara creado y se debe seleccionar desde el apartado de kernel, el nombre del entorno es sim(Python 3.10.13)

# %% [markdown]
# luego hay que ejecutar correctamente la app con streamlit run app.py o en este caso como lo indica el github streamlit run main.py
#
# conda activate sim
# streamlit run simpy-streamlit-tutorial\main.py
#
# pero al hacer esto nos dimos cuenta que no muestra nada en el navegador ya que no existe un app.py al copiar el repositorio y estabamos usando el main.py
# por lo que habia que ejecutar los diferentes app que vienen incluidos dentro de D:\U\visualizacion\trabajo unidad 4\simpy-streamlit-tutorial\content\03_streamlit
# dentro de 03_streamlit vienen varios app.py que se pueden mostrar con ayuda de streamlit
#
# por ejemplo app_to_deploy.py que al ejecutar
# streamlit run simpy-streamlit-tutorial\content\03_streamlit\app_to_deploy.py (todo esto en la consola)
# muestra el siguiente streamlit

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Se puede ver como cargo en streamlit un simulador de un centro de llamadas de atención de urgencias (urgent care call centre), siendo todo de forma interactiva gracias a streamlit

# %%
# streamlit run simpy-streamlit-tutorial\content\03_streamlit\app_to_deploy.py esto es lo que se ejecuta en la terminal

# %% [markdown]
# otro ejemplo seria usando streamlit run simpy-streamlit-tutorial\content\03_streamlit\basic_app.py
# y su resultado es el siguiente

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Aqui se ve el mismo simulador de centro de llamadas anterior pero con nuevos resultados y sin ser interactivo
